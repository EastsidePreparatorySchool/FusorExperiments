# %% [markdown]
# # Purpose:
# Test the HV setup, recording the Variac's voltage, the CW's voltage (kv), and the NST's voltage.

# %% [markdown]
# #Procedure:
#
# After pretest setup (checking connections):
#
# 1) Turned on the variac.
#
# 2) Turned the variac up by intervals of 20 up to 140.
#
# 3) The variac was turned down to 0 slowly.

# %% [markdown]
# # Data:

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
from pandas import ExcelWriter
from pandas import ExcelFile
from matplotlib.pyplot import figure

data = pd.read_excel(r'C:\Users\zhillger\OneDrive - Eastside Preparatory School\Desktop\Fusor\New Board Tests.xlsx', sheet_name='Sheet1')

df = pd.DataFrame(data, columns = ['Variac (V)'])
df = df[0:155]

df2 = pd.DataFrame(data, columns = ['CW Out (kV)'])
df2 = df2[0:155]

x = df.values.tolist()
y = df2.values.tolist()

df3 = pd.DataFrame(data, columns = ['Variac (V)'])
df3 = df3[160:309]

df4 = pd.DataFrame(data, columns = ['CW Out (kV)'])
df4 = df4[160:309]

x2 = df3.values.tolist()
y2 = df4.values.tolist()

figure(figsize=(12,8))
plt.xlabel("Variac (V)")
plt.ylabel("CW Out (kV)")

plt.scatter(x,y)
plt.scatter(x2,y2)

# %% [markdown]
# #Data for Both Boards

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
from pandas import ExcelWriter
from pandas import ExcelFile
from matplotlib.pyplot import figure


#df = df[0:155]

df = pd.read_csv(r'C:\Users\zhillger\OneDrive - Eastside Preparatory School\Desktop\Fusor\CWTwoStage400Mohm.txt', delim_whitespace=True)  
#print(df)
df = pd.DataFrame(df, columns = ['3'])
x = df.values.tolist()

df2 = pd.read_csv(r'C:\Users\zhillger\OneDrive - Eastside Preparatory School\Desktop\Fusor\CWTwoStage400Mohm.txt', delim_whitespace=True)  
df2 = pd.DataFrame(df2, columns = ['9'])
y = df2.values.tolist()

#print(df2)

#df2 = pd.DataFrame(data, columns = ['CW Out (kV)'])
#df2 = df2[0:155]

#df2 = pd.read_csv('/content/CWTwoStage400Mohm.txt', delim_whitespace=True)  
#df2 = pd.read_csv('/content/CWTwoStage400Mohm.txt', delimiter=' ')


#x = df.values.tolist()
#y = df2.values.tolist()


figure(figsize=(12,8))
plt.xlabel("Variac (V)")
plt.ylabel("CW Out (kV)")

plt.scatter(x,y)

# %% [markdown]
# # Conclusion:
#
# Both boards work as expected. In the next test, both boards will be tested together and a higher voltage should be achieved.
