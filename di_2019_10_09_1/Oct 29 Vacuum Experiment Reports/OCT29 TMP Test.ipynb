# %% [markdown]
# #OCT29 TMP Test
#
# ###Full pumpdown and testing needle valve

# %% [markdown]
# ##Purpose:
# Gather more data on the pirani gauge display/voltage meter relationship.
# Determine whether we can control the needle valve opening, and document this.
#
# ##Setup:
#
# 1. Gather all parts:
# 	- Cart
# 	- Pirani gauge display
# 	- Pirani gauge display transformer
# 	- Multimeter for back of Pirani gauge voltage
# 	- TMP (turbo molecular pump) transformer
# 	- Rough pump
# 	- KF flange
# 2. Connect rough pump to turbo pump with KF flange
# 3. Plug in the Pirani gauge display and transformer
# 	- Plug multimeter into the back of the Pirani gauge display (make sure to get positive and negative right)
# 4. Plug in rough pump
# 5. **Ground the cart**.
# 6. Plug in TMP transformer
# 7. Plug in the TMP controller to its two ethernet ports and a computer running the program.
# 8. Restart the program between tests.
#
#
# ##What we wIll do:
# Pump down. Once pumped down to 0 PG, we will open the needle valve to bleed in small amounts of air. We will then observe the change in pressure.
#
# What we will read out:
# The Pirani gauge reading (shortened to PG) and the Pirani gauge voltage meter.
#
# All readings are taken via video and significant points are noted below in notes and observations.

# %% [markdown]
# ##Notes and Observations
# Run 1:
# - TMP on at .5 PG
# - TMP got down to about .07 then turned off and went back up.
#
# Run 2:
# - Power supply was switched to a proper 24V
# - Needle valve tests were successful:
#
# - Ball closed
#     3.99 V
#     .000 PG
# - 0 Notch
#     3.80 V
#     .000 PG
# - 1 Notch
#     3.90 V
#     .000 PG
# - 2 Notch
#     4.04 V
#     .000 PG
# - 3 Notch
#     3.97 V
#     .000 PG
# - 4 Notch
#     3.93 V
#     .000 PG
# - 5 Notch
#     3.89 V
#     .000 PG
# - 6 Notch
#     3.91 V
#     .000 PG
# - 7 Notch
#     4.00 V
#     .000 PG
# - 8 Notch
#     3.85 V
#     .000 PG
# - 9 Notch
#     3.94 V
#     .000 PG
# - 10 Notch
#     4.07 V
#     .000 PG
# - 11 Notch
#     3.90 V
#     .000 PG
# - 12 Notch
#     3.98 V
#     .000 PG
# - 13 Notch
#     4.00 V
#     .000 PG
# - 14 Notch
#     4.05 V
#     .000 PG
# - 15 Notch
#     3.97 V
#     .000 PG
# - 16 Notch
#     4.02 V
#     .000 PG
# - 17 Notch
#     4.02 V
#     .000 PG
# - 18 Notch
#     3.96 V
#     .000 PG
# - 19 Notch
#     3.95 V
#     .000 PG
# - 20 Notch
#     3.96 V
#     .000 PG
# going too slowly, jumping by 5
# - 25 Notch
#     4.00 V
#     .000 PG
# - 30 Notch
#     4.02 V
#     .000 PG
# - 35 Notch
#     4.06 V
#     .000 PG
# - 40 Notch
#     4.01 V
#     .000 PG
# - 45 Notch
#     4.06 V
#     .000 PG
# - 50 Notch
#     3.87 V
#     .000 PG
# - 55 Notch
#     3.80 V
#     .000 PG
# - 60 Notch
#     3.68 V
#     .000 PG
# - 65 Notch
#     3.79 V
#     .000 PG
# - 70 Notch
#     3.84 V
#     .000 PG
# - 75 Notch
#     3.80 V
#     .000 PG
# - 80 Notch
#     3.80 V
#     .000 PG
# - 85 Notch
#     3.65 V
#     .000 PG
# - 90 Notch
#     3.80 V
#     .000 PG
# - 95 Notch
#     3.07 V !!!
#     .000 PG
# - 100 Notch
#     -1.54 V
#     .009 PG
# - 105 Notch
#     -5.84 V
#     .550 PG
# 100 is the cutoff for useful closedness
#
# Back to 95 notches for more precise measuements
# - 95 Notch
#     3.30 V
#     .000 PG
# - 96 Notch
#     2.79 V
#     .000 PG
# - 97 Notch
#     2.34 V
#     .000 PG
# - 98 Notch
#     1.26 V
#     .000 PG
# - 99 Notch
#     -0.32 V
#     .002 PG
# - 100 Notch
#     -1.50 V
#     .009 PG
# - 101 Notch
#     -3.33 V
#     .030 PG
# - 102 Notch
#     -4.55 V
#     .150 PG
# - 103 Notch
#     -5.30 V
#     .360 PG
# - 104 Notch
#     -5.69 V
#     .500 PG
# - 105 Notch
#     -6.00 V
#     .680 PG
